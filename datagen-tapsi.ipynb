# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Set a start time
start_time = datetime(2024, 1, 1, 8, 0, 0)  # You can customize the start time

# Number of drivers
n_drivers = 5  # You can customize the number of drivers

# Maximum distance a driver can move in latitude and longitude
max_distance = 0.01  # You can customize this value

# Initialize drivers with random starting locations
drivers = pd.DataFrame({
        'Driver_ID': np.arange(1, n_drivers + 1),
        'Latitude':  None,
        'Longitude': None
        })

lat = np.random.uniform(-90, 90, n_drivers)
long = np.random.uniform(-180, 180, n_drivers)
locations = np.vstack((lat, long))

# Initialize an empty DataFrame to store the data
columns = ['Timestamp', 'Latitude', 'Longitude', 'Driver_ID']
dataset = pd.DataFrame(columns=columns)

# Function to generate random movement within a maximum distance
def apply_random_movement(locations, size, max_distance=10):
    delta = np.random.normal(0, max_distance/4, 2*size).reshape((2, -1))
    new_loc = delta + locations
    return np.vstack((
        np.clip(new_loc[0, :], -90, 90), 
        np.clip(new_loc[1, :], -180, 180)
    ))

# Loop to generate the dataset for each driver
n_iterations = 10
n_batch = 3

for _ in range(n_iterations):
    selected = np.random.choice(n_drivers, n_batch, replace=True)
    
    X = locations[:, selected]
    X = apply_random_movement(X, n_batch)


    wait_time = np.random.uniform(1, 60, size=n_batch)  # Random time between 1 and 60 seconds  
    wait_time = wait_time.cumsum()
    
    # Wait for a random time
    start_time += timedelta(minutes=wait_time)

    # Update timestamp
    timestamp = start_time.strftime('%Y-%m-%d %H:%M:%S')
        
    locations[:, selected] = X


print(locations.ravel())
locations = apply_random_movement(locations[:, np.arange(n_batch)], n_batch)
print(locations.ravel())

# i = np.arange(batch_size)
# apply_random_movement(drivers['Latitude'][i], drivers['Latitude'][i], batch_size)
# drivers['Latitude'][0] = np.arange(3)

# dataset.iloc[]

# drivers['Latitude']

# for _ in range(iterations):

#     current_location = np.array([drivers['Latitude'][driver_id - 1], drivers['Longitude'][driver_id - 1]])
#     # Update the location with random movement

#     new_latitude, new_longitude = generate_random_movement(current_location, max_distance)
#     for i in range(num_rows_per_driver):

#         # Save the status as a row in the dataset
#         row = {'Timestamp': timestamp, 'Latitude': new_latitude, 'Longitude': new_longitude, 'Driver_ID': driver_id}
#         dataset = dataset.append(row, ignore_index=True)

#         # Update the current location for the next iteration
#         current_location = np.array([new_latitude, new_longitude])

# # Print the generated dataset
# print(dataset)
# Out:
# [  48.3402827   -21.99586886   68.6312115    68.18037762   36.74465994
#    -2.18829436  -43.47885641  128.70704436   31.43368256 -131.06038105]
# [ 44.18125986 -23.12261811  70.28066169  -1.9468744  -43.26400371
#  128.73141914]

# %%
å
